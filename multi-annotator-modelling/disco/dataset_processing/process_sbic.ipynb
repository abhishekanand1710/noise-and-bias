# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
train_df = pd.read_csv('./SBIC.v2/SBIC.v2.trn.csv')
train_df.head()
# Out:
#    whoTarget  intentYN  sexYN sexReason  offensiveYN annotatorGender  \
# 0        0.0      0.66    0.0       NaN          1.0           woman
# 1        0.0      0.66    0.0       NaN          0.5             man
# 2        0.0      0.33    0.0       NaN          0.5             man
# 3        1.0      1.00    0.0       NaN          1.0             man
# 4        1.0      1.00    0.0       NaN          1.0             man
#
#   annotatorMinority sexPhrase  speakerMinorityYN             WorkerId  \
# 0               NaN       NaN                NaN -8935932304856669427
# 1               NaN       NaN                NaN  6347880360297734464
# 2               NaN       NaN                NaN -7452610791699819066
# 3               NaN       NaN                0.0  -500114755446676507
# 4               NaN       NaN                0.0  -500114755446676507
#
#                             HITId annotatorPolitics annotatorRace  \
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112900 entries, 0 to 112899
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   whoTarget          65969 non-null   float64
#  1   intentYN           112900 non-null  float64
#  2   sexYN              112900 non-null  float64
#  3   sexReason          10380 non-null   object
#  4   offensiveYN        110883 non-null  float64
#  5   annotatorGender    112899 non-null  object
#  6   annotatorMinority  29030 non-null   object
#  7   sexPhrase          10393 non-null   object
#  8   speakerMinorityYN  45463 non-null   float64
#  9   WorkerId           112900 non-null  int64
#  10  HITId              112900 non-null  object
#  11  annotatorPolitics  112899 non-null  object
#  12  annotatorRace      112899 non-null  object
#  13  annotatorAge       112899 non-null  float64
#  14  post               112900 non-null  object
# ...

# %%
train_df['intentYN'].value_counts()
# Out:
# 1.00    42662
# 0.00    40718
# 0.66    15633
# 0.33    13887
# Name: intentYN, dtype: int64

# %%
len(train_df['WorkerId'].unique())
# Out:
# 263

# %%
len(train_df['HITId'].unique())
# Out:
# 35933

# %%
dev_df = pd.read_csv('./SBIC.v2/SBIC.v2.dev.csv')
dev_df.head()
# Out:
#    whoTarget  intentYN  sexYN sexReason  offensiveYN annotatorGender  \
# 0        1.0       1.0    0.0       NaN          1.0           woman
# 1        1.0       1.0    0.0       NaN          1.0           woman
# 2        1.0       1.0    1.0      rape          1.0           woman
# 3        1.0       1.0    1.0      rape          1.0           woman
# 4        1.0       1.0    1.0      rape          1.0           woman
#
#   annotatorMinority         sexPhrase  speakerMinorityYN             WorkerId  \
# 0               NaN               NaN                0.0  2428559182657536645
# 1               NaN               NaN                0.0  2428559182657536645
# 2             women  rape white women                0.0  7162172225567546910
# 3             women  rape white women                0.0  7162172225567546910
# 4             women  rape white women                0.0  7162172225567546910
#
#                             HITId annotatorPolitics annotatorRace  \
# ...

# %%
dev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16738 entries, 0 to 16737
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   whoTarget          10996 non-null  float64
#  1   intentYN           16738 non-null  float64
#  2   sexYN              16738 non-null  float64
#  3   sexReason          1433 non-null   object
#  4   offensiveYN        16497 non-null  float64
#  5   annotatorGender    16738 non-null  object
#  6   annotatorMinority  4247 non-null   object
#  7   sexPhrase          1433 non-null   object
#  8   speakerMinorityYN  8557 non-null   float64
#  9   WorkerId           16738 non-null  int64
#  10  HITId              16738 non-null  object
#  11  annotatorPolitics  16738 non-null  object
#  12  annotatorRace      16738 non-null  object
#  13  annotatorAge       16738 non-null  float64
#  14  post               16738 non-null  object
#  15  targetMinority     8166 non-null   object
# ...

# %%
len(dev_df['HITId'].unique())
# Out:
# 4680

# %%
test_df = pd.read_csv('./SBIC.v2/SBIC.v2.tst.csv')
test_df.head()
# Out:
#    whoTarget  intentYN  sexYN             sexReason  offensiveYN  \
# 0        0.0      0.66    0.0                   NaN          1.0
# 1        NaN      0.00    0.0                   NaN          0.0
# 2        0.0      0.66    0.0                   NaN          0.5
# 3        0.0      1.00    1.0  calls a woman a slut          1.0
# 4        0.0      0.66    0.0                   NaN          0.5
#
#   annotatorGender annotatorMinority  \
# 0           woman             women
# 1             man               NaN
# 2             man               NaN
# 3             man               NaN
# 4           woman               NaN
#
#                                           sexPhrase  speakerMinorityYN  \
# 0                                               NaN                NaN
# 1                                               NaN                NaN
# 2                                               NaN                NaN
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17501 entries, 0 to 17500
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   whoTarget          11974 non-null  float64
#  1   intentYN           17501 non-null  float64
#  2   sexYN              17501 non-null  float64
#  3   sexReason          1646 non-null   object
#  4   offensiveYN        17269 non-null  float64
#  5   annotatorGender    17501 non-null  object
#  6   annotatorMinority  4298 non-null   object
#  7   sexPhrase          1647 non-null   object
#  8   speakerMinorityYN  9538 non-null   float64
#  9   WorkerId           17501 non-null  int64
#  10  HITId              17501 non-null  object
#  11  annotatorPolitics  17501 non-null  object
#  12  annotatorRace      17501 non-null  object
#  13  annotatorAge       17501 non-null  float64
#  14  post               17501 non-null  object
#  15  targetMinority     9200 non-null   object
# ...

# %%
len(test_df['HITId'].unique())
# Out:
# 4705

# %%
label_map = {0: 0, 0.33: 0, 0.66: 1, 1.0: 1}

# %%
train_df['annotator_label'] =  train_df['intentYN'].apply(lambda x: label_map[x])
dev_df['annotator_label'] =  dev_df['intentYN'].apply(lambda x: label_map[x])
test_df['annotator_label'] =  test_df['intentYN'].apply(lambda x: label_map[x])

# %%
# !mkdir SBIC_processed

# %%
train_df.to_csv('./SBIC_processed/train.csv', index=False)
dev_df.to_csv('./SBIC_processed/dev.csv', index=False)
test_df.to_csv('./SBIC_processed/test.csv', index=False)

# %%
df = pd.concat([train_df, dev_df, test_df])
df.head()
# Out:
#    whoTarget  intentYN  sexYN sexReason  offensiveYN annotatorGender  \
# 0        0.0      0.66    0.0       NaN          1.0           woman
# 1        0.0      0.66    0.0       NaN          0.5             man
# 2        0.0      0.33    0.0       NaN          0.5             man
# 3        1.0      1.00    0.0       NaN          1.0             man
# 4        1.0      1.00    0.0       NaN          1.0             man
#
#   annotatorMinority sexPhrase  speakerMinorityYN             WorkerId  \
# 0               NaN       NaN                NaN -8935932304856669427
# 1               NaN       NaN                NaN  6347880360297734464
# 2               NaN       NaN                NaN -7452610791699819066
# 3               NaN       NaN                0.0  -500114755446676507
# 4               NaN       NaN                0.0  -500114755446676507
#
#                             HITId annotatorPolitics annotatorRace  \
# ...

# %%
df.to_csv('./SBIC_processed/full.csv', index=False)
