# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/sbic_v2/full.csv')
df.head()
# Out:
#    whoTarget  intentYN  sexYN sexReason  offensiveYN annotatorGender  \
# 0        0.0      0.66    0.0       NaN          1.0           woman
# 1        0.0      0.66    0.0       NaN          0.5             man
# 2        0.0      0.33    0.0       NaN          0.5             man
# 3        1.0      1.00    0.0       NaN          1.0             man
# 4        1.0      1.00    0.0       NaN          1.0             man
#
#   annotatorMinority sexPhrase  speakerMinorityYN             WorkerId  \
# 0               NaN       NaN                NaN -8935932304856669427
# 1               NaN       NaN                NaN  6347880360297734464
# 2               NaN       NaN                NaN -7452610791699819066
# 3               NaN       NaN                0.0  -500114755446676507
# 4               NaN       NaN                0.0  -500114755446676507
#
#                             HITId annotatorPolitics annotatorRace  \
# ...

# %%
df = df.rename(columns = {"WorkerId":"annotator_id", "HITId":"comment_id"})
df.head()
# Out:
#    whoTarget  intentYN  sexYN sexReason  offensiveYN annotatorGender  \
# 0        0.0      0.66    0.0       NaN          1.0           woman
# 1        0.0      0.66    0.0       NaN          0.5             man
# 2        0.0      0.33    0.0       NaN          0.5             man
# 3        1.0      1.00    0.0       NaN          1.0             man
# 4        1.0      1.00    0.0       NaN          1.0             man
#
#   annotatorMinority sexPhrase  speakerMinorityYN         annotator_id  \
# 0               NaN       NaN                NaN -8935932304856669427
# 1               NaN       NaN                NaN  6347880360297734464
# 2               NaN       NaN                NaN -7452610791699819066
# 3               NaN       NaN                0.0  -500114755446676507
# 4               NaN       NaN                0.0  -500114755446676507
#
#                        comment_id annotatorPolitics annotatorRace  \
# ...

# %%
df['comment_id'].nunique()
# Out:
# 45318

# %%
df['annotator_id'].nunique()
# Out:
# 307

# %%
df_grouped = df.groupby('comment_id').size()
df_grouped.head()
# Out:
# comment_id
# 301KG0KX9CF8K5JONRZNDVHCKE12H0    4
# 301KG0KX9CF8K5JONRZNDVHCKNPH2L    6
# 301KG0KX9CF8K5JONRZNDVHCKNQ2H7    1
# 301KG0KX9CF8K5JONRZNDVHCPOAH2D    3
# 301KG0KX9CF8K5JONRZNDVHCPOB2HZ    3
# dtype: int64

# %%
df_grouped.describe()
# Out:
# count    45318.000000
# mean         3.246811
# std          1.221759
# min          1.000000
# 25%          3.000000
# 50%          3.000000
# 75%          3.000000
# max         20.000000
# dtype: float64

# %%
df_grouped = df.groupby('annotator_id').size()
df_grouped.head()
# Out:
# annotator_id
# -9147217452378128741     10
# -9041581465162765065      7
# -9025462013607560094      2
# -9009092953903040528      3
# -8935932304856669427    518
# dtype: int64

# %%
df_grouped.describe()
# Out:
# count     307.000000
# mean      479.280130
# std       829.572868
# min         1.000000
# 25%         2.000000
# 50%        20.000000
# 75%       634.500000
# max      4698.000000
# dtype: float64
